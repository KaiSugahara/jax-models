# %%
########################################
# ライブラリ
########################################

import jax
import jax.numpy as jnp

from flax import linen as nn
from flax.training import train_state
import optax

from tqdm import trange as tqdm_range
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
########################################
# モデルの定義
########################################

class ANN(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(features=100)(x)
        x = nn.relu(x)
        x = nn.Dense(features=3)(x)
        x = nn.softmax(x)
        return x

# %%
########################################
# 損失関数
########################################

@jax.jit
def loss_function(params, X, y):
    # 予測値計算
    predict = ann.apply({'params': params}, X)
    # 損失を計算
    loss = jnp.mean(-jnp.sum(y * jnp.log(predict), axis=1))
    return loss

# %%
########################################
# ミニバッチ学習
########################################

@jax.jit
def train_batch(batch_idx, state):
    # ミニバッチを抽出
    target_indices = jax.lax.dynamic_slice_in_dim(train_indices, (batch_idx*batch_length), batch_length)
    X, y = X_train[target_indices], y_train[target_indices]
    # 損失と勾配を計算
    loss, grads = jax.value_and_grad(loss_function)(state.params, X, y)
    # 更新
    state = state.apply_gradients(grads=grads)
    return state

# %%
########################################
# データセットの読み込み
########################################

iris_dataset = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], test_size=0.25,  random_state=0)
X_train, X_test, y_train, y_test = jax.device_put(X_train), jax.device_put(X_test), jax.device_put(y_train), jax.device_put(y_test)
y_train = jnp.eye(3)[y_train]
y_test = jnp.eye(3)[y_test]

# %%
########################################
# 学習してみる
########################################

ann = ANN()
params = ann.init(jax.random.PRNGKey(0), jnp.ones([1, 4]))['params']

# SGDを定義
learning_rate, momentum = 0.01, 0.01
tx = optax.sgd(learning_rate, momentum)

# パラメータの管理
state = train_state.TrainState.create(apply_fn=ann.apply, params=params, tx=tx)

# エポック数
nums_epoch = 100
# バッチサイズ
batch_size = 5

# バッチ数
batch_length = X_train.shape[0] // batch_size

# nums_epoch回 学習する
for epoch_idx in range(nums_epoch):
    
    # 訓練データのインデックスをシャッフル
    train_indices = jax.random.permutation(jax.random.PRNGKey(epoch_idx+1), X_train.shape[0])
    # ミニバッチ学習で更新
    state = jax.lax.fori_loop(0, batch_length, train_batch, state)
    
    # 誤差の確認
    print(
        "訓練誤差:",
        '{:.3f}'.format(loss_function(state.params, X_train, y_train)),
        "汎化誤差:",
        '{:.3f}'.format(loss_function(state.params, X_test, y_test)),
        f"【 Epoch: {epoch_idx} / {nums_epoch} 】"
    )
# Out:
# 訓練誤差: 0.878 汎化誤差: 1.171 【 Epoch: 0 / 100 】
# 訓練誤差: 0.729 汎化誤差: 1.004 【 Epoch: 1 / 100 】
# 訓練誤差: 0.650 汎化誤差: 0.916 【 Epoch: 2 / 100 】
# 訓練誤差: 0.589 汎化誤差: 0.848 【 Epoch: 3 / 100 】
# 訓練誤差: 0.535 汎化誤差: 0.787 【 Epoch: 4 / 100 】
# 訓練誤差: 0.485 汎化誤差: 0.728 【 Epoch: 5 / 100 】
# 訓練誤差: 0.436 汎化誤差: 0.669 【 Epoch: 6 / 100 】
# 訓練誤差: 0.389 汎化誤差: 0.609 【 Epoch: 7 / 100 】
# 訓練誤差: 0.342 汎化誤差: 0.546 【 Epoch: 8 / 100 】
# 訓練誤差: 0.297 汎化誤差: 0.481 【 Epoch: 9 / 100 】
# 訓練誤差: 0.255 汎化誤差: 0.413 【 Epoch: 10 / 100 】
# 訓練誤差: 0.219 汎化誤差: 0.346 【 Epoch: 11 / 100 】
# 訓練誤差: 0.196 汎化誤差: 0.292 【 Epoch: 12 / 100 】
# 訓練誤差: 0.186 汎化誤差: 0.258 【 Epoch: 13 / 100 】
# 訓練誤差: 0.181 汎化誤差: 0.239 【 Epoch: 14 / 100 】
# 訓練誤差: 0.093 汎化誤差: 0.173 【 Epoch: 58 / 100 】
# 訓練誤差: 0.093 汎化誤差: 0.173 【 Epoch: 59 / 100 】
# 訓練誤差: 0.092 汎化誤差: 0.172 【 Epoch: 60 / 100 】
# 訓練誤差: 0.092 汎化誤差: 0.172 【 Epoch: 61 / 100 】
# 訓練誤差: 0.091 汎化誤差: 0.172 【 Epoch: 62 / 100 】
# 訓練誤差: 0.091 汎化誤差: 0.172 【 Epoch: 63 / 100 】
# 訓練誤差: 0.090 汎化誤差: 0.172 【 Epoch: 64 / 100 】
# 訓練誤差: 0.090 汎化誤差: 0.172 【 Epoch: 65 / 100 】
# 訓練誤差: 0.090 汎化誤差: 0.171 【 Epoch: 66 / 100 】
# 訓練誤差: 0.089 汎化誤差: 0.171 【 Epoch: 67 / 100 】
# 訓練誤差: 0.089 汎化誤差: 0.171 【 Epoch: 68 / 100 】
# 訓練誤差: 0.088 汎化誤差: 0.171 【 Epoch: 69 / 100 】
# 訓練誤差: 0.088 汎化誤差: 0.171 【 Epoch: 70 / 100 】
# 訓練誤差: 0.088 汎化誤差: 0.171 【 Epoch: 71 / 100 】
# 訓練誤差: 0.087 汎化誤差: 0.171 【 Epoch: 72 / 100 】
# 訓練誤差: 0.087 汎化誤差: 0.171 【 Epoch: 73 / 100 】
# 訓練誤差: 0.087 汎化誤差: 0.171 【 Epoch: 74 / 100 】
# 訓練誤差: 0.086 汎化誤差: 0.170 【 Epoch: 75 / 100 】
# 訓練誤差: 0.086 汎化誤差: 0.170 【 Epoch: 76 / 100 】
# 訓練誤差: 0.086 汎化誤差: 0.170 【 Epoch: 77 / 100 】
# 訓練誤差: 0.085 汎化誤差: 0.170 【 Epoch: 78 / 100 】
# 訓練誤差: 0.085 汎化誤差: 0.170 【 Epoch: 79 / 100 】
# 訓練誤差: 0.085 汎化誤差: 0.170 【 Epoch: 80 / 100 】
# 訓練誤差: 0.085 汎化誤差: 0.170 【 Epoch: 81 / 100 】
# 訓練誤差: 0.084 汎化誤差: 0.170 【 Epoch: 82 / 100 】
# 訓練誤差: 0.084 汎化誤差: 0.170 【 Epoch: 83 / 100 】
# 訓練誤差: 0.084 汎化誤差: 0.170 【 Epoch: 84 / 100 】
# 訓練誤差: 0.084 汎化誤差: 0.170 【 Epoch: 85 / 100 】
# 訓練誤差: 0.083 汎化誤差: 0.170 【 Epoch: 86 / 100 】
# 訓練誤差: 0.083 汎化誤差: 0.170 【 Epoch: 87 / 100 】
# 訓練誤差: 0.083 汎化誤差: 0.170 【 Epoch: 88 / 100 】
# 訓練誤差: 0.083 汎化誤差: 0.170 【 Epoch: 89 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 90 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 91 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 92 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 93 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 94 / 100 】
# 訓練誤差: 0.082 汎化誤差: 0.170 【 Epoch: 95 / 100 】
# 訓練誤差: 0.081 汎化誤差: 0.170 【 Epoch: 96 / 100 】
# 訓練誤差: 0.081 汎化誤差: 0.170 【 Epoch: 97 / 100 】
# 訓練誤差: 0.081 汎化誤差: 0.170 【 Epoch: 98 / 100 】
# 訓練誤差: 0.081 汎化誤差: 0.170 【 Epoch: 99 / 100 】
